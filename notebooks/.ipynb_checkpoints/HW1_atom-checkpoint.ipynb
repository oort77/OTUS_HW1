# %%
# -*- coding: utf-8 -*-
#  File: HW1_atom.ipynb
#  Project: 'OTUS Homework #1'
#  Created by Gennady Matveev (gm@og.ly) on 16-12-2021.

# %% [markdown]
# # **$Homework 1$**

# %% [markdown]
# Goals:
# - Compare four gradient boosting algorithms: sklearn GBT, XGBoost, CatBoost, LightGBM
# - Implement EDA, preprocessing, and feature engineering
# - Tune hyperparameters

# %% [markdown]
# Means:
# - All meaningful programming will be done in ATOM
#     https://tvdboom.github.io/ATOM/about/

# %% [markdown]
# Dataset:
# - Student Performance on an entrance examination Data Set  https://archive.ics.uci.edu/ml/datasets/Student+Performance+on+an+entrance+examination

# %% [markdown]
# Abbreviations:
# - EDA: exploratory data analysis
# - BO: bayesian optimization
# - FE: feature engineering
# - DFS: deep feature synthesis

# %% [markdown]
# ### Import libraries and setup notebook

# %%
import pandas as pd
import numpy as np
from atom import ATOMClassifier
from scipy.io import arff
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.display import display, HTML
import warnings
# import sys
# sys.path.append('../src/')
# from utilities import *

display(HTML("<style>.container { width:80% !important; }</style>"))
# %config InlineBackend.figure_format = 'retina'
# plt.rcParams['figure.figsize']=(10,5)
sns.set(rc = {'figure.figsize':(8,5)})
warnings.filterwarnings("ignore")

random_state = 17
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ### Load data

# %%
data, meta = arff.loadarff('../data/CEE_DATA.arff')
df = pd.DataFrame(data).applymap(lambda x: x.decode('utf-8'))

# %% [markdown]
# #### Small bit of preprocessing - XGBoost needs special target encoding

# %%
df["Performance"] = df["Performance"].map(
    {'Average': 0, 'Good': 1, 'Vg': 2, 'Excellent': 3})

# %% [markdown]
# ####  Split target from features

# %%
X = df[df.columns[1:]]
y = df[df.columns[0]]

# %% [markdown]
# ### EDA

# %% [markdown]
# #### Basic dataset information

# %%
print(meta)
df.head(3)
# Out:
# Dataset: CEEData
# 	Performance's type is nominal, range is ('Excellent', 'Vg', 'Good', 'Average')
# 	Gender's type is nominal, range is ('male', 'female')
# 	Caste's type is nominal, range is ('General', 'OBC', 'SC', 'ST')
# 	coaching's type is nominal, range is ('NO', 'WA', 'OA')
# 	time's type is nominal, range is ('ONE', 'TWO', 'THREE', 'FOUR', 'FIVE', 'SEVEN')
# 	Class_ten_education's type is nominal, range is ('SEBA', 'OTHERS', 'CBSE')
# 	twelve_education's type is nominal, range is ('AHSEC', 'CBSE', 'OTHERS')
# 	medium's type is nominal, range is ('ENGLISH', 'OTHERS', 'ASSAMESE')
# 	Class_ X_Percentage's type is nominal, range is ('Excellent', 'Vg', 'Good', 'Average')
# 	Class_XII_Percentage's type is nominal, range is ('Excellent', 'Vg', 'Good', 'Average')
# 	Father_occupation's type is nominal, range is ('DOCTOR', 'SCHOOL_TEACHER', 'BUSINESS', 'COLLEGE_TEACHER', 'OTHERS', 'BANK_OFFICIAL', 'ENGINEER', 'CULTIVATOR')
# 	Mother_occupation's type is nominal, range is ('OTHERS', 'HOUSE_WIFE', 'SCHOOL_TEACHER', 'DOCTOR', 'COLLEGE_TEACHER', 'BANK_OFFICIAL', 'BUSINESS', 'CULTIVATOR', 'ENGINEER')
#    Performance Gender    Caste coaching time Class_ten_education  \
# 0            3   male  General       NO  ONE                SEBA
# 1            3   male      OBC       WA  TWO                SEBA
# 2            3   male      OBC       OA  TWO              OTHERS
#
#   twelve_education   medium Class_ X_Percentage Class_XII_Percentage  \
# 0            AHSEC  ENGLISH           Excellent            Excellent
# 1            AHSEC   OTHERS           Excellent            Excellent
# 2             CBSE  ENGLISH           Excellent            Excellent
#
#   Father_occupation Mother_occupation
# 0            DOCTOR            OTHERS
# 1    SCHOOL_TEACHER        HOUSE_WIFE
# 2          BUSINESS        HOUSE_WIFE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 666 entries, 0 to 665
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Performance           666 non-null    int64
#  1   Gender                666 non-null    object
#  2   Caste                 666 non-null    object
#  3   coaching              666 non-null    object
#  4   time                  666 non-null    object
#  5   Class_ten_education   666 non-null    object
#  6   twelve_education      666 non-null    object
#  7   medium                666 non-null    object
#  8   Class_ X_Percentage   666 non-null    object
#  9   Class_XII_Percentage  666 non-null    object
#  10  Father_occupation     666 non-null    object
#  11  Mother_occupation     666 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 62.6+ KB

# %%
# Features
X.describe().T
# Out:
#                      count unique         top freq
# Gender                 666      2        male  355
# Caste                  666      4     General  329
# coaching               666      3          WA  449
# time                   666      6         TWO  368
# Class_ten_education    666      3        SEBA  396
# twelve_education       666      3       AHSEC  368
# medium                 666      3     ENGLISH  536
# Class_ X_Percentage    666      4   Excellent  511
# Class_XII_Percentage   666      4   Excellent  398
# Father_occupation      666      8      OTHERS  277
# Mother_occupation      666      9  HOUSE_WIFE  442

# %% [markdown]
# #### Target values distribution

# %%
sns.countplot(df['Performance'], data=df)
plt.suptitle('Target distribution by classes')

print(f'Target distribution by classes:')
df["Performance"].value_counts(
    normalize=True).apply(lambda x: f'{x*100:.1f} %')
# Out:
# Target distribution by classes:
# 1    31.5 %
# 2    29.7 %
# 0    23.6 %
# 3    15.2 %
# Name: Performance, dtype: object

# %% [markdown]
# #### twelve_education and Caste features seems to be important

# %%
# Performance vs twelve_education
_ = sns.countplot(x=df['twelve_education'], hue=df['Performance'], data=df);

# %%
# Performance vs Caste
_ = sns.countplot(x=df['Caste'], hue=df['Performance'], data=df)

# %% [markdown]
# #### Dataset profile report

# %%
# X.profile_report()

# %% [markdown]
# Observations:
# - Dataset has no missiong values
# - Roughly 10% of rows have duplicates - will ignore this, may be a coincidence
# - All features are categorical with smallish number of unique values
# - Many features have very uneven distributions with predominance of a single class
# - Target values are distributed fairly equally between classes
# - A number of feature pairs exhibit sizable correlation that may lead to their collinearity
# - Only a few features have significant correlation with the target

# %% [markdown]
# ### Pipeline

# %% [markdown]
# #### Initialise classifier

# %%
atom = ATOMClassifier(X, y, test_size=0.25, verbose=2,
                      warnings=False, random_state=random_state)  # n_jobs=1,
# Out:
# << ================== ATOM ================== >>
# Algorithm task: multiclass classification.
#
# Dataset stats ==================== >>
# Shape: (666, 12)
# Scaled: False
# Categorical features: 11 (100.0%)
# Duplicate samples: 44 (6.6%)
# -------------------------------------
# Train set size: 500
# Test set size: 166
# -------------------------------------
# |    |     dataset |       train |        test |
# | -- | ----------- | ----------- | ----------- |
# | 0  |   157 (1.6) |   124 (1.8) |    33 (1.1) |
# | 1  |   210 (2.1) |   156 (2.2) |    54 (1.7) |
# | 2  |   198 (2.0) |   150 (2.1) |    48 (1.5) |
# | 3  |   101 (1.0) |    70 (1.0) |    31 (1.0) |

# %% [markdown]
# #### Preprocessing - encode features

# %%
atom.encode()
# Out:
# Fitting Encoder...
# Encoding categorical columns...
#  --> Ordinal-encoding feature Gender. Contains 2 classes.
#  --> OneHot-encoding feature Caste. Contains 4 classes.
#  --> OneHot-encoding feature coaching. Contains 3 classes.
#  --> OneHot-encoding feature time. Contains 6 classes.
#  --> OneHot-encoding feature Class_ten_education. Contains 3 classes.
#  --> OneHot-encoding feature twelve_education. Contains 3 classes.
#  --> OneHot-encoding feature medium. Contains 3 classes.
#  --> OneHot-encoding feature Class_ X_Percentage. Contains 4 classes.
#  --> OneHot-encoding feature Class_XII_Percentage. Contains 4 classes.
#  --> OneHot-encoding feature Father_occupation. Contains 8 classes.
#  --> OneHot-encoding feature Mother_occupation. Contains 9 classes.

# %%
# atom.title_fontsize = 16
# with atom.canvas(6, 2, title="Distribution of features by class"):  # , filename="canvas"
#     for col in X.columns:
#         atom.plot_distribution(col, title=f"{col}")  # , figsize=(14,7))

# %% [markdown]
# #### Setup Decision Tree classifier as a baseline model and check its performance

# %%
atom.run(
    models='tree',
    metric = ["roc_auc_ovr", "f1_weighted"]
)
# Out:
# Training ========================= >>
# Models: Tree
# Metric: roc_auc_ovr, f1_weighted
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.9964   f1_weighted: 0.9337
# Test evaluation --> roc_auc_ovr: 0.6708   f1_weighted: 0.4791
# Time elapsed: 0.015s
# -------------------------------------------------
# Total time: 0.016s
#
#
# Final results ==================== >>
# Duration: 0.016s
# -------------------------------------
# Decision Tree --> roc_auc_ovr: 0.6708   f1_weighted: 0.4791 ~

# %% [markdown]
# #### Run the pipeline with default hyperparameters

# %% [markdown]
# ##### Choose models and metrics

# %%
models = ['GBM', 'XGB', 'CATB', 'LGB']
metric = ["roc_auc_ovr", "f1_weighted"]

# %%
# Fit the pipeline with the selected models
atom.run(
    models=models,
    metric=metric
)
# Out:
# Training ========================= >>
# Models: GBM, XGB, CatB, LGB
# Metric: roc_auc_ovr, f1_weighted
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.9443   f1_weighted: 0.7843
# Test evaluation --> roc_auc_ovr: 0.7958   f1_weighted: 0.5544
# Time elapsed: 0.326s
# -------------------------------------------------
# Total time: 0.326s
#
#
# Results for XGBoost:
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.9953   f1_weighted: 0.9319
# Test evaluation --> roc_auc_ovr: 0.7516   f1_weighted: 0.4646
# Time elapsed: 0.475s
# -------------------------------------------------
# Total time: 0.476s
#
#
# Results for CatBoost:
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.9391   f1_weighted: 0.7616
# Test evaluation --> roc_auc_ovr: 0.7966   f1_weighted: 0.5308
# Time elapsed: 1.710s
# -------------------------------------------------
# Total time: 1.710s
#
#
# Results for LightGBM:
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.9825   f1_weighted: 0.8876
# Test evaluation --> roc_auc_ovr: 0.7656   f1_weighted: 0.4777
# Time elapsed: 0.174s
# -------------------------------------------------
# Total time: 0.174s
#
#
# Final results ==================== >>
# Duration: 2.686s
# -------------------------------------
# Gradient Boosting Machine --> roc_auc_ovr: 0.7958   f1_weighted: 0.5544
# XGBoost                   --> roc_auc_ovr: 0.7516   f1_weighted: 0.4646 ~
# CatBoost                  --> roc_auc_ovr: 0.7966   f1_weighted: 0.5308 !
# LightGBM                  --> roc_auc_ovr: 0.7656   f1_weighted: 0.4777 ~

# %% [markdown]
# #### Check train and test metrics

# %% [markdown]
# Todo: transform atom.results

# %%
# atom.results
atom.plot_results(figsize=(8,5))
atom.results[[ "metric_train", "metric_test"]].applymap(lambda x: (round(x[0],4), round(x[1],4)))
# Out:
#           metric_train       metric_test
# Tree  (0.9964, 0.9337)  (0.6708, 0.4791)
# GBM   (0.9443, 0.7843)  (0.7958, 0.5544)
# XGB   (0.9953, 0.9319)  (0.7516, 0.4646)
# CatB  (0.9391, 0.7616)  (0.7966, 0.5308)
# LGB   (0.9825, 0.8876)  (0.7656, 0.4777)

# %% [markdown]
# Observation:
# - All estimators perform better than baseline model - sanity check passed
# - So far GBM and CatBoost seem more promising than XGBoost and LightGBM
# - XGBoost and LightGBM are most likely overfitting

# %% [markdown]
# #### Check feature importance for one of estimators

# %%
atom.bar_plot('XGB', show=20, figsize=(8,10))

# %% [markdown]
# #### Bayesian optimization of hyperparameters

# %%
# Tune hyperparameters
atom.branch = "hp_bo"
atom.run(
    models=["GBM", "XGB", "CATB", "LGB"],
    metric=metric,
    n_calls=7,
    n_initial_points=3,
    bo_params={
        #                 "dimensions":[Integer(100, 1000, name="n_estimators"),
        #                 Integer(3, 6, name="max_depth"),
        #                 Real(0.01, 1, "log-uniform", name="learning_rate")],
        "base_estimator": "RF", "max_time": 10000,# "plot": True
    },
    n_bootstrap=5, verbose=2
)
# Out:
# New branch hp_bo successfully created!
#
# Training ========================= >>
# Models: GBM, XGB, CatB, LGB
# Metric: roc_auc_ovr, f1_weighted
#
#
# Running BO for Gradient Boosting Machine...
# | call             | learning_rate | n_estimators | subsample | criterion | min_samples_split | min_samples_leaf | max_depth | max_features | ccp_alpha | roc_auc_ovr | best_roc_auc_ovr | f1_weighted | best_f1_weighted |    time | total_time |
# | ---------------- | ------------- | ------------ | --------- | --------- | ----------------- | ---------------- | --------- | ------------ | --------- | ----------- | ---------------- | ----------- | ---------------- | ------- | ---------- |
# | Initial point 1  |          0.02 |          400 |       0.6 | friedma.. |                 6 |                8 |         5 |          0.5 |     0.022 |      0.7347 |           0.7347 |      0.3487 |           0.3487 |  4.481s |     4.489s |
# | Initial point 2  |          0.52 |          194 |       1.0 | friedma.. |                 8 |                7 |        10 |          0.6 |      0.01 |      0.7164 |           0.7347 |      0.4785 |           0.4785 |  2.735s |     7.341s |
# | Initial point 3  |          0.02 |          443 |       0.7 | friedma.. |                 8 |                3 |         7 |          0.6 |     0.028 |      0.7328 |           0.7347 |       0.349 |           0.4785 |  5.881s |    13.292s |
# | Iteration 4      |          0.07 |          198 |       0.8 |       mse |                 8 |                8 |         8 |          0.6 |     0.005 |      0.7501 |           0.7501 |      0.4741 |           0.4785 |  2.746s |    16.273s |
# | Iteration 5      |          0.26 |          123 |       0.9 |       mse |                 7 |               10 |         2 |          0.8 |      0.03 |      0.7173 |           0.7501 |      0.3501 |           0.4785 |  1.353s |    17.857s |
# | Iteration 6      |          0.44 |           79 |       0.9 |       mse |                17 |                6 |         1 |          0.7 |     0.003 |      0.7482 |           0.7501 |      0.4899 |           0.4899 |  0.788s |    18.875s |
# | Iteration 7      |          0.76 |          279 |       1.0 | friedma.. |                 2 |               17 |         9 |          0.7 |     0.033 |      0.6525 |           0.7501 |        0.35 |           0.4899 |  3.475s |    22.581s |
#
# Results for Gradient Boosting Machine:
# Bayesian Optimization ---------------------------
# Best call --> Iteration 4
# Best parameters --> {'learning_rate': 0.07, 'n_estimators': 198, 'subsample': 0.8, 'criterion': 'mse', 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_depth': 8, 'max_features': 0.6, 'ccp_alpha': 0.005}
# Best evaluation --> roc_auc_ovr: 0.7501   f1_weighted: 0.4741
# Time elapsed: 22.827s
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.7868   f1_weighted: 0.4949
# Test evaluation --> roc_auc_ovr: 0.7846   f1_weighted: 0.3983
# Time elapsed: 0.628s
# Bootstrap ---------------------------------------
# Evaluation --> roc_auc_ovr: 0.7658 ± 0.0089   f1_weighted: 0.4388 ± 0.017
# Time elapsed: 3.060s
# -------------------------------------------------
# Total time: 26.516s
#
#
# Running BO for XGBoost...
# | call             | n_estimators | learning_rate | max_depth |   gamma | min_child_weight | subsample | colsample_bytree | reg_alpha | reg_lambda | roc_auc_ovr | best_roc_auc_ovr | f1_weighted | best_f1_weighted |    time | total_time |
# | ---------------- | ------------ | ------------- | --------- | ------- | ---------------- | --------- | ---------------- | --------- | ---------- | ----------- | ---------------- | ----------- | ---------------- | ------- | ---------- |
# | Initial point 1  |          261 |          0.12 |         7 |    0.89 |               14 |       0.9 |              0.8 |         1 |          1 |      0.7608 |           0.7608 |      0.5005 |           0.5005 |  2.618s |     2.624s |
# | Initial point 2  |          258 |          0.52 |         9 |    0.95 |                4 |       0.8 |              0.3 |      0.01 |        0.1 |      0.7592 |           0.7608 |      0.5073 |           0.5073 |  2.290s |     4.984s |
# | Initial point 3  |          293 |          0.13 |         6 |     0.3 |                6 |       0.5 |              0.6 |         1 |          0 |      0.7646 |           0.7646 |      0.4746 |           0.5073 |  2.659s |     7.712s |
# | Iteration 4      |          303 |          0.17 |         5 |    0.02 |               10 |       0.6 |              1.0 |       100 |          1 |         0.5 |           0.7646 |      0.0986 |           0.5073 |  1.564s |     9.529s |
# | Iteration 5      |          349 |          0.02 |         3 |    0.49 |               19 |       1.0 |              1.0 |       100 |          1 |         0.5 |           0.7646 |      0.0986 |           0.5073 |  1.521s |    11.302s |
# | Iteration 6      |           97 |          0.08 |         1 |    0.27 |                9 |       0.7 |              0.8 |         0 |         10 |      0.7473 |           0.7646 |      0.4838 |           0.5073 |  0.550s |    12.105s |
# | Iteration 7      |          190 |          0.01 |         6 |    0.91 |               13 |       0.6 |              0.8 |         0 |         10 |        0.76 |           0.7646 |      0.4805 |           0.5073 |  1.891s |    14.247s |
#
# Results for XGBoost:
# Bayesian Optimization ---------------------------
# Best call --> Initial point 3
# Best parameters --> {'n_estimators': 293, 'learning_rate': 0.13, 'max_depth': 6, 'gamma': 0.3, 'min_child_weight': 6, 'subsample': 0.5, 'colsample_bytree': 0.6, 'reg_alpha': 1, 'reg_lambda': 0}
# Best evaluation --> roc_auc_ovr: 0.7646   f1_weighted: 0.4746
# Time elapsed: 14.624s
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.9112   f1_weighted: 0.7149
# Test evaluation --> roc_auc_ovr: 0.7921   f1_weighted: 0.4967
# Time elapsed: 0.699s
# Bootstrap ---------------------------------------
# Evaluation --> roc_auc_ovr: 0.77 ± 0.0095   f1_weighted: 0.49 ± 0.0284
# Time elapsed: 2.978s
# -------------------------------------------------
# Total time: 18.303s
#
#
# Running BO for CatBoost...
# | call             | n_estimators | learning_rate | max_depth | subsample | colsample_bylevel | reg_lambda | roc_auc_ovr | best_roc_auc_ovr | f1_weighted | best_f1_weighted |    time | total_time |
# | ---------------- | ------------ | ------------- | --------- | --------- | ----------------- | ---------- | ----------- | ---------------- | ----------- | ---------------- | ------- | ---------- |
# | Initial point 1  |          261 |          0.12 |         1 |       0.5 |               0.9 |          1 |      0.7647 |           0.7647 |      0.4823 |           0.4823 |  0.360s |     0.365s |
# | Initial point 2  |          488 |          0.03 |         6 |       1.0 |               0.3 |         10 |      0.7631 |           0.7647 |      0.4687 |           0.4823 |  3.807s |     4.255s |
# | Initial point 3  |          339 |          0.53 |         8 |       0.5 |               0.8 |          1 |      0.7575 |           0.7647 |      0.4908 |           0.4908 |  9.731s |    14.067s |
# | Iteration 4      |          249 |          0.03 |         7 |       0.7 |               0.4 |        0.1 |      0.7577 |           0.7647 |      0.4936 |           0.4936 |  3.444s |    17.761s |
# | Iteration 5      |          170 |          0.22 |         6 |       0.6 |               0.6 |          0 |      0.7642 |           0.7647 |      0.4952 |           0.4952 |  1.481s |    19.490s |
# | Iteration 6      |          441 |          0.02 |         5 |       0.6 |               0.4 |          0 |       0.753 |           0.7647 |      0.4838 |           0.4952 |  2.003s |    21.741s |
# | Iteration 7      |          127 |          0.45 |         9 |       0.9 |               0.3 |        0.1 |      0.7323 |           0.7647 |      0.4692 |           0.4952 |  6.570s |    28.559s |
#
# Results for CatBoost:
# Bayesian Optimization ---------------------------
# Best call --> Initial point 1
# Best parameters --> {'n_estimators': 261, 'learning_rate': 0.12, 'max_depth': 1, 'subsample': 0.5, 'colsample_bylevel': 0.9, 'reg_lambda': 1}
# Best evaluation --> roc_auc_ovr: 0.7647   f1_weighted: 0.4823
# Time elapsed: 28.829s
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.8302   f1_weighted: 0.5408
# Test evaluation --> roc_auc_ovr: 0.8012   f1_weighted: 0.496
# Time elapsed: 0.103s
# Bootstrap ---------------------------------------
# Evaluation --> roc_auc_ovr: 0.7795 ± 0.0075   f1_weighted: 0.4803 ± 0.0266
# Time elapsed: 0.395s
# -------------------------------------------------
# Total time: 29.329s
#
#
# Running BO for LightGBM...
# | call             | n_estimators | learning_rate | max_depth | num_leaves | min_child_weight | min_child_samples | subsample | colsample_bytree | reg_alpha | reg_lambda | roc_auc_ovr | best_roc_auc_ovr | f1_weighted | best_f1_weighted |    time | total_time |
# | ---------------- | ------------ | ------------- | --------- | ---------- | ---------------- | ----------------- | --------- | ---------------- | --------- | ---------- | ----------- | ---------------- | ----------- | ---------------- | ------- | ---------- |
# | Initial point 1  |          261 |          0.12 |         1 |         36 |               14 |                14 |       0.5 |              0.4 |         1 |        100 |      0.7487 |           0.7487 |      0.4766 |           0.4766 |  0.610s |     0.616s |
# | Initial point 2  |          204 |          0.78 |        -1 |         26 |                7 |                19 |       0.7 |              0.5 |         0 |       0.01 |      0.7477 |           0.7487 |      0.4946 |           0.4946 |  0.709s |     1.395s |
# | Initial point 3  |          337 |          0.04 |         2 |         32 |               14 |                20 |       0.7 |              0.5 |         1 |          1 |      0.7577 |           0.7577 |      0.4726 |           0.4946 |  0.869s |     2.332s |
# | Iteration 4      |          399 |          0.41 |         1 |         25 |               20 |                26 |       0.5 |              0.8 |       100 |       0.01 |         0.5 |           0.7577 |      0.1484 |           0.4946 |  0.383s |     2.999s |
# | Iteration 5      |          311 |          0.23 |         6 |         27 |                1 |                28 |       0.8 |              1.0 |         1 |       0.01 |      0.7575 |           0.7577 |      0.4952 |           0.4952 |  0.557s |     3.839s |
# | Iteration 6      |          191 |           0.1 |         1 |         30 |                6 |                15 |       1.0 |              0.3 |         1 |       0.01 |      0.7521 |           0.7577 |      0.4999 |           0.4999 |  0.459s |     4.583s |
# | Iteration 7      |          338 |          0.58 |         1 |         22 |                3 |                15 |       0.6 |              0.9 |         0 |        100 |      0.7757 |           0.7757 |      0.4987 |           0.4999 |  0.566s |     5.434s |
#
# Results for LightGBM:
# Bayesian Optimization ---------------------------
# Best call --> Iteration 7
# Best parameters --> {'n_estimators': 338, 'learning_rate': 0.58, 'max_depth': 1, 'num_leaves': 22, 'min_child_weight': 3, 'min_child_samples': 15, 'subsample': 0.6, 'colsample_bytree': 0.9, 'reg_alpha': 0, 'reg_lambda': 100}
# Best evaluation --> roc_auc_ovr: 0.7757   f1_weighted: 0.4987
# Time elapsed: 5.722s
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.8365   f1_weighted: 0.5839
# Test evaluation --> roc_auc_ovr: 0.8057   f1_weighted: 0.5282
# Time elapsed: 0.163s
# Bootstrap ---------------------------------------
# Evaluation --> roc_auc_ovr: 0.7797 ± 0.0108   f1_weighted: 0.5 ± 0.0229
# Time elapsed: 0.488s
# -------------------------------------------------
# Total time: 6.375s
#
#
# Final results ==================== >>
# Duration: 1m:21s
# -------------------------------------
# Gradient Boosting Machine --> roc_auc_ovr: 0.7658 ± 0.0089   f1_weighted: 0.4388 ± 0.017
# XGBoost                   --> roc_auc_ovr: 0.77 ± 0.0095   f1_weighted: 0.49 ± 0.0284
# CatBoost                  --> roc_auc_ovr: 0.7795 ± 0.0075   f1_weighted: 0.4803 ± 0.0266
# LightGBM                  --> roc_auc_ovr: 0.7797 ± 0.0108   f1_weighted: 0.5 ± 0.0229 !

# %% [markdown]
# Todo: transform atom.results to a better readeable format!!!

# %%
atom.plot_results(figsize=(8,5))
atom.results#.applymap(lambda x: (round(x[0],4), round(x[1],4))) #"metric_bo",
# Out:
#                                      metric_bo  time_bo  \
# Tree                                      None     None
# GBM   [0.7500830112452228, 0.4740967999809277]  22.827s
# XGB   [0.7645960282486175, 0.4746050621836613]  14.624s
# CatB  [0.7646548177994179, 0.4822783523002248]  28.829s
# LGB   [0.7757423097804267, 0.4986652515363528]   5.722s
#
#                                    metric_train  \
# Tree   [0.9964365661835731, 0.9337175449877864]
# GBM   [0.7867743232683171, 0.49490364106178053]
# XGB    [0.9111537643536732, 0.7148656560021315]
# CatB    [0.830234993291373, 0.5407768702011418]
# LGB    [0.8365003744966811, 0.5839456956321168]
#
#                                     metric_test time_fit  \
# Tree    [0.670755443407984, 0.4790655245479738]   0.015s
# GBM    [0.7846376370990996, 0.3982980155459547]   0.628s
# XGB   [0.7920752088893832, 0.49674088529510213]   0.699s
# CatB  [0.8011786786738857, 0.49602951959594815]   0.103s
# LGB    [0.8057490085982971, 0.5282436181499551]   0.163s
#
#                                 mean_bootstrap  \
# Tree                                      None
# GBM   [0.7658454527130338, 0.4387907269911895]
# XGB     [0.770019695583227, 0.489983679531316]
# CatB  [0.7795356796079618, 0.4802511990602999]
# LGB   [0.7797333643728892, 0.5000211478550401]
#
#                                      std_bootstrap time_bootstrap     time
# Tree                                          None           None   0.016s
# GBM   [0.008881012599669877, 0.017014323948331724]         3.060s  26.516s
# XGB   [0.009524106719565346, 0.028413501476214933]         2.978s  18.303s
# CatB  [0.007522025765807117, 0.026593523423678534]         0.395s  29.329s
# LGB    [0.010837657209438467, 0.02294852521002329]         0.488s   6.375s

# %% [markdown]
# Observation:
# - BO leads to models performing more or less on par with XGBoost leading in ROC_AUC and LightGBM in F1_weighted
# - Overall performance of models has not increased after H/P BO with n_calls=25, n_initial_points=10,
#     it takes several hundred of BO calls to reach ROC_AUC 0.8 and F1_weighted 0,51, probably due
#     to high dimensionality of H/P space

# %% [markdown]
# ### Feature engineering

# %% [markdown]
# #### DFS in a separate pipeline branch

# %%
atom.verbose = 2
atom.branch = "fe"
atom.feature_generation("dfs", n_features=100, operators=["add", "sub", "mul"])
# Out:
# New branch fe successfully created!
# Fitting FeatureGenerator...
# Creating new features...
#  --> 148 new features were added to the dataset.

# %% [markdown]
# #### Make feature selection

# %%
# Check for multicollinearity and use RFECV to reduce the number
atom.feature_selection(
    strategy="RFECV",
    solver="RF",
    n_features=50,
    scoring="logloss",
    max_correlation=0.98,
)
# Out:
# Fitting FeatureSelector...
# Performing feature selection ...
#  --> Feature time_SEVEN * time_THREE was removed due to low variance. Value 0.0 repeated in 100% of the rows.
#  --> Feature Class_ X_Percentage_Average * time_FIVE was removed due to low variance. Value 0.0 repeated in 100% of the rows.
#  --> Feature Father_occupation_OTHERS * Mother_occupation_BUSINESS was removed due to low variance. Value 0.0 repeated in 100% of the rows.
#  --> Feature Father_occupation_ENGINEER * Mother_occupation_CULTIVATOR was removed due to low variance. Value 0.0 repeated in 100% of the rows.
#  --> Feature Father_occupation_ENGINEER * Mother_occupation_DOCTOR was removed due to low variance. Value 0.0 repeated in 100% of the rows.
#  --> Feature Father_occupation_CULTIVATOR * Father_occupation_OTHERS was removed due to low variance. Value 0.0 repeated in 100% of the rows.
#  --> Feature Father_occupation_CULTIVATOR * time_SEVEN was removed due to low variance. Value 0.0 repeated in 100% of the rows.
#  --> Feature Mother_occupation_CULTIVATOR * Mother_occupation_OTHERS was removed due to low variance. Value 0.0 repeated in 100% of the rows.
#  --> Feature Mother_occupation_CULTIVATOR * Mother_occupation_SCHOOL_TEACHER was removed due to low variance. Value 0.0 repeated in 100% of the rows.
#  --> Feature Gender - Mother_occupation_CULTIVATOR was removed due to collinearity with another feature.
#  --> Feature Caste_General + Mother_occupation_CULTIVATOR was removed due to collinearity with another feature.
#  --> Feature coaching_WA + Mother_occupation_CULTIVATOR was removed due to collinearity with another feature.
#  --> Feature coaching_NO + time_SEVEN was removed due to collinearity with another feature.
#  --> Feature Class_XII_Percentage_Vg - time_SEVEN was removed due to collinearity with another feature.
#  --> The RFECV selected 62 features from the dataset.
#    >>> Dropping feature Caste_General * Father_occupation_SCHOOL_TEACHER (rank 35).
#    >>> Dropping feature Caste_OBC (rank 8).
#    >>> Dropping feature Caste_SC * Class_ X_Percentage_Vg (rank 46).
#    >>> Dropping feature Caste_ST * time_ONE (rank 25).
#    >>> Dropping feature coaching_WA * Mother_occupation_COLLEGE_TEACHER (rank 45).
#    >>> Dropping feature coaching_NO (rank 10).
#    >>> Dropping feature coaching_OA (rank 11).
#    >>> Dropping feature coaching_OA * Mother_occupation_BANK_OFFICIAL (rank 66).
#    >>> Dropping feature time_FOUR (rank 57).
#    >>> Dropping feature time_FOUR * twelve_education_AHSEC (rank 61).
#    >>> Dropping feature time_ONE (rank 6).
#    >>> Dropping feature time_ONE * twelve_education_OTHERS (rank 67).
#    >>> Dropping feature time_THREE (rank 14).
#    >>> Dropping feature time_SEVEN (rank 68).
#    >>> Dropping feature time_FIVE (rank 72).
#    >>> Dropping feature time_FIVE + time_FOUR (rank 56).
#    >>> Dropping feature time_FIVE + time_SEVEN (rank 65).
#    >>> Dropping feature Class_ten_education_CBSE (rank 12).
#    >>> Dropping feature Class_ten_education_CBSE * Mother_occupation_BANK_OFFICIAL (rank 70).
#    >>> Dropping feature Class_ten_education_CBSE + twelve_education_OTHERS (rank 17).
#    >>> Dropping feature Class_ten_education_SEBA (rank 5).
#    >>> Dropping feature Class_ten_education_SEBA * Father_occupation_CULTIVATOR (rank 50).
#    >>> Dropping feature Class_ten_education_SEBA * time_FOUR (rank 53).
#    >>> Dropping feature Class_ten_education_OTHERS (rank 41).
#    >>> Dropping feature Class_ten_education_OTHERS - Father_occupation_DOCTOR (rank 4).
#    >>> Dropping feature twelve_education_CBSE (rank 24).
#    >>> Dropping feature twelve_education_AHSEC (rank 31).
#    >>> Dropping feature twelve_education_OTHERS (rank 47).
#    >>> Dropping feature medium_ENGLISH (rank 7).
#    >>> Dropping feature medium_ENGLISH - twelve_education_OTHERS (rank 23).
#    >>> Dropping feature medium_OTHERS (rank 13).
#    >>> Dropping feature medium_ASSAMESE (rank 19).
#    >>> Dropping feature medium_ASSAMESE + time_FOUR (rank 32).
#    >>> Dropping feature Class_ X_Percentage_Excellent (rank 9).
#    >>> Dropping feature Class_ X_Percentage_Excellent * twelve_education_CBSE (rank 20).
#    >>> Dropping feature Class_ X_Percentage_Vg (rank 34).
#    >>> Dropping feature Class_ X_Percentage_Vg - Mother_occupation_DOCTOR (rank 21).
#    >>> Dropping feature Class_ X_Percentage_Good (rank 40).
#    >>> Dropping feature Class_ X_Percentage_Good * Class_XII_Percentage_Vg (rank 52).
#    >>> Dropping feature Class_ X_Percentage_Good + Mother_occupation_BUSINESS (rank 37).
#    >>> Dropping feature Class_ X_Percentage_Good + time_FOUR (rank 33).
#    >>> Dropping feature Class_ X_Percentage_Average (rank 49).
#    >>> Dropping feature Class_ X_Percentage_Average * Father_occupation_SCHOOL_TEACHER (rank 62).
#    >>> Dropping feature Class_ X_Percentage_Average * Mother_occupation_OTHERS (rank 63).
#    >>> Dropping feature Class_XII_Percentage_Excellent * twelve_education_OTHERS (rank 71).
#    >>> Dropping feature Class_XII_Percentage_Vg * coaching_NO (rank 36).
#    >>> Dropping feature Class_XII_Percentage_Good (rank 27).
#    >>> Dropping feature Class_XII_Percentage_Good * Father_occupation_BUSINESS (rank 48).
#    >>> Dropping feature Class_XII_Percentage_Good * Gender (rank 43).
#    >>> Dropping feature Class_XII_Percentage_Average (rank 44).
#    >>> Dropping feature Class_XII_Percentage_Average + Mother_occupation_COLLEGE_TEACHER (rank 30).
#    >>> Dropping feature Class_XII_Percentage_Average - Mother_occupation_BANK_OFFICIAL (rank 39).
#    >>> Dropping feature Father_occupation_DOCTOR (rank 26).
#    >>> Dropping feature Father_occupation_DOCTOR * Mother_occupation_DOCTOR (rank 51).
#    >>> Dropping feature Father_occupation_ENGINEER (rank 18).
#    >>> Dropping feature Father_occupation_ENGINEER - Mother_occupation_BUSINESS (rank 29).
#    >>> Dropping feature Father_occupation_SCHOOL_TEACHER (rank 15).
#    >>> Dropping feature Father_occupation_BANK_OFFICIAL (rank 28).
#    >>> Dropping feature Father_occupation_CULTIVATOR (rank 38).
#    >>> Dropping feature Father_occupation_CULTIVATOR * twelve_education_OTHERS (rank 73).
#    >>> Dropping feature Father_occupation_COLLEGE_TEACHER (rank 16).
#    >>> Dropping feature Mother_occupation_OTHERS (rank 2).
#    >>> Dropping feature Mother_occupation_SCHOOL_TEACHER (rank 22).
#    >>> Dropping feature Mother_occupation_SCHOOL_TEACHER * time_THREE (rank 59).
#    >>> Dropping feature Mother_occupation_SCHOOL_TEACHER + time_FOUR (rank 3).
#    >>> Dropping feature Mother_occupation_BANK_OFFICIAL (rank 58).
#    >>> Dropping feature Mother_occupation_COLLEGE_TEACHER (rank 42).
#    >>> Dropping feature Mother_occupation_CULTIVATOR (rank 64).
#    >>> Dropping feature Mother_occupation_DOCTOR (rank 54).
#    >>> Dropping feature Mother_occupation_BUSINESS (rank 60).
#    >>> Dropping feature Mother_occupation_ENGINEER (rank 55).
#    >>> Dropping feature Mother_occupation_ENGINEER * twelve_education_AHSEC (rank 69).

# %%
# atom.collinear

# %%
# After applying RFECV, plot the score per number of features
atom.plot_rfecv()

# %% [markdown]
# #### Run models with new set of features

# %%
# Check models' performance now
# Add a tag to the model's acronym to not overwrite previous one
atom.run("GBM_fe")
atom.run("XGB_fe")
atom.run("CATB_fe")
atom.run("LGB_fe")
# Out:
# Training ========================= >>
# Models: GBM_fe
# Metric: roc_auc_ovr, f1_weighted
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.9638   f1_weighted: 0.8186
# Test evaluation --> roc_auc_ovr: 0.7522   f1_weighted: 0.4956
# Time elapsed: 0.450s
# -------------------------------------------------
# Total time: 0.450s
#
#
# Final results ==================== >>
# Duration: 0.450s
# -------------------------------------
# Gradient Boosting Machine --> roc_auc_ovr: 0.7522   f1_weighted: 0.4956 ~
#
# Training ========================= >>
# Models: XGB_fe
# Metric: roc_auc_ovr, f1_weighted
#
#
# Results for XGBoost:
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.9962   f1_weighted: 0.9319
# Test evaluation --> roc_auc_ovr: 0.7529   f1_weighted: 0.4852
# Time elapsed: 0.531s
# -------------------------------------------------
# Total time: 0.531s
#
#
# Final results ==================== >>
# Duration: 0.531s
# -------------------------------------
# XGBoost --> roc_auc_ovr: 0.7529   f1_weighted: 0.4852 ~
#
# Training ========================= >>
# Models: CatB_fe
# Metric: roc_auc_ovr, f1_weighted
#
#
# Results for CatBoost:
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.9318   f1_weighted: 0.7319
# Test evaluation --> roc_auc_ovr: 0.7774   f1_weighted: 0.4718
# Time elapsed: 3.078s
# -------------------------------------------------
# Total time: 3.078s
#
#
# Final results ==================== >>
# Duration: 3.078s
# -------------------------------------
# CatBoost --> roc_auc_ovr: 0.7774   f1_weighted: 0.4718
#
# Training ========================= >>
# Models: LGB_fe
# Metric: roc_auc_ovr, f1_weighted
#
#
# Results for LightGBM:
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.9915   f1_weighted: 0.9159
# Test evaluation --> roc_auc_ovr: 0.7626   f1_weighted: 0.4913
# Time elapsed: 0.214s
# -------------------------------------------------
# Total time: 0.214s
#
#
# Final results ==================== >>
# Duration: 0.214s
# -------------------------------------
# LightGBM --> roc_auc_ovr: 0.7626   f1_weighted: 0.4913 ~

# %% [markdown]
# #### Compare intermediate results

# %%
atom.results
# Out:
#                                         metric_bo  time_bo  \
# Tree                                         None     None
# GBM      [0.7500830112452228, 0.4740967999809277]  22.827s
# XGB      [0.7645960282486175, 0.4746050621836613]  14.624s
# CatB     [0.7646548177994179, 0.4822783523002248]  28.829s
# LGB      [0.7757423097804267, 0.4986652515363528]   5.722s
# GBM_fe                                       None     None
# XGB_fe                                       None     None
# CatB_fe                                      None     None
# LGB_fe                                       None     None
#
#                                       metric_train  \
# Tree      [0.9964365661835731, 0.9337175449877864]
# GBM      [0.7867743232683171, 0.49490364106178053]
# XGB       [0.9111537643536732, 0.7148656560021315]
# CatB       [0.830234993291373, 0.5407768702011418]
# LGB       [0.8365003744966811, 0.5839456956321168]
# GBM_fe     [0.9638399584413581, 0.818625445620794]
# XGB_fe    [0.9962152534568058, 0.9319183410057182]
# CatB_fe   [0.9318048022812051, 0.7319470312808214]
# LGB_fe    [0.9915362129980414, 0.9158509768070945]
#
#                                        metric_test time_fit  \
# Tree       [0.670755443407984, 0.4790655245479738]   0.015s
# GBM       [0.7846376370990996, 0.3982980155459547]   0.628s
# XGB      [0.7920752088893832, 0.49674088529510213]   0.699s
# CatB     [0.8011786786738857, 0.49602951959594815]   0.103s
# LGB       [0.8057490085982971, 0.5282436181499551]   0.163s
# GBM_fe   [0.7522426898517245, 0.49563009578572503]   0.450s
# XGB_fe     [0.752934046379244, 0.4851876680967236]   0.531s
# CatB_fe  [0.7774437155792638, 0.47184951522996194]   3.078s
# LGB_fe   [0.7626422933875867, 0.49125595296963526]   0.214s
#
#                                    mean_bootstrap  \
# Tree                                         None
# GBM      [0.7658454527130338, 0.4387907269911895]
# XGB        [0.770019695583227, 0.489983679531316]
# CatB     [0.7795356796079618, 0.4802511990602999]
# LGB      [0.7797333643728892, 0.5000211478550401]
# GBM_fe                                       None
# XGB_fe                                       None
# CatB_fe                                      None
# LGB_fe                                       None
#
#                                         std_bootstrap time_bootstrap     time
# Tree                                             None           None   0.016s
# GBM      [0.008881012599669877, 0.017014323948331724]         3.060s  26.516s
# XGB      [0.009524106719565346, 0.028413501476214933]         2.978s  18.303s
# CatB     [0.007522025765807117, 0.026593523423678534]         0.395s  29.329s
# LGB       [0.010837657209438467, 0.02294852521002329]         0.488s   6.375s
# GBM_fe                                           None           None   0.450s
# XGB_fe                                           None           None   0.531s
# CatB_fe                                          None           None   3.078s
# LGB_fe                                           None           None   0.214s

# %% [markdown]
# Observation:
# - Feature engineering doesn't show much promise as models run with default parameters perform better in both metrics

# %% [markdown]
# #### Run FE-modified models and tune hyperparameters with bayesian optimization

# %% [markdown]
# Todo: eleminate line wrap in atom.run output

# %%
atom.branch = "fe_bo"
# Tune hyperparameters
atom.run(
    models=["GBM_fe", "XGB_fe", "CATB_fe", "LGB_fe"],
    metric=metric,
    n_calls=7,
    n_initial_points=3,
    bo_params={
        #                 "dimensions":[Integer(100, 1000, name="n_estimators"),
        #                 Integer(3, 6, name="max_depth"),
        #                 Real(0.01, 1, "log-uniform", name="learning_rate")],
        "base_estimator": "RF", "max_time": 10000,# "plot": True
        #                 "early_stopping":5
    },
    n_bootstrap=5, verbose=2
)
# Out:
# New branch fe_bo successfully created!
#
# Training ========================= >>
# Models: GBM_fe, XGB_fe, CatB_fe, LGB_fe
# Metric: roc_auc_ovr, f1_weighted
#
#
# Running BO for Gradient Boosting Machine...
# | call             | learning_rate | n_estimators | subsample | criterion | min_samples_split | min_samples_leaf | max_depth | max_features | ccp_alpha | roc_auc_ovr | best_roc_auc_ovr | f1_weighted | best_f1_weighted |    time | total_time |
# | ---------------- | ------------- | ------------ | --------- | --------- | ----------------- | ---------------- | --------- | ------------ | --------- | ----------- | ---------------- | ----------- | ---------------- | ------- | ---------- |
# | Initial point 1  |          0.02 |          400 |       0.6 | friedma.. |                 6 |                8 |         5 |          0.5 |     0.022 |      0.7316 |           0.7316 |      0.3504 |           0.3504 |  5.471s |     5.478s |
# | Initial point 2  |          0.52 |          194 |       1.0 | friedma.. |                 8 |                7 |        10 |          0.6 |      0.01 |      0.7141 |           0.7316 |      0.4391 |           0.4391 |  3.986s |     9.533s |
# | Initial point 3  |          0.02 |          443 |       0.7 | friedma.. |                 8 |                3 |         7 |          0.6 |     0.028 |      0.7299 |           0.7316 |       0.349 |           0.4391 |  7.853s |    17.455s |
# | Iteration 4      |          0.07 |          198 |       0.8 |       mse |                 8 |                8 |         8 |          0.6 |     0.005 |      0.7571 |           0.7571 |      0.4963 |           0.4963 |  3.759s |    21.443s |
# | Iteration 5      |          0.26 |          123 |       0.9 |       mse |                 7 |               10 |         2 |          0.8 |      0.03 |      0.7213 |           0.7571 |      0.3496 |           0.4963 |  1.652s |    23.325s |
# | Iteration 6      |          0.44 |           79 |       0.9 |       mse |                17 |                6 |         1 |          0.7 |     0.003 |      0.7427 |           0.7571 |      0.4809 |           0.4963 |  0.873s |    24.428s |
# | Iteration 7      |           0.1 |          187 |       0.5 |       mse |                19 |                7 |         6 |          0.8 |     0.017 |      0.7317 |           0.7571 |      0.4402 |           0.4963 |  2.915s |    27.572s |
#
# Results for Gradient Boosting Machine:
# Bayesian Optimization ---------------------------
# Best call --> Iteration 4
# Best parameters --> {'learning_rate': 0.07, 'n_estimators': 198, 'subsample': 0.8, 'criterion': 'mse', 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_depth': 8, 'max_features': 0.6, 'ccp_alpha': 0.005}
# Best evaluation --> roc_auc_ovr: 0.7571   f1_weighted: 0.4963
# Time elapsed: 27.806s
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.7882   f1_weighted: 0.501
# Test evaluation --> roc_auc_ovr: 0.7559   f1_weighted: 0.3999
# Time elapsed: 0.886s
# Bootstrap ---------------------------------------
# Evaluation --> roc_auc_ovr: 0.7566 ± 0.0061   f1_weighted: 0.4308 ± 0.0261
# Time elapsed: 4.355s
# -------------------------------------------------
# Total time: 33.047s
#
#
# Running BO for XGBoost...
# | call             | n_estimators | learning_rate | max_depth |   gamma | min_child_weight | subsample | colsample_bytree | reg_alpha | reg_lambda | roc_auc_ovr | best_roc_auc_ovr | f1_weighted | best_f1_weighted |    time | total_time |
# | ---------------- | ------------ | ------------- | --------- | ------- | ---------------- | --------- | ---------------- | --------- | ---------- | ----------- | ---------------- | ----------- | ---------------- | ------- | ---------- |
# | Initial point 1  |          261 |          0.12 |         7 |    0.89 |               14 |       0.9 |              0.8 |         1 |          1 |      0.7558 |           0.7558 |      0.5082 |           0.5082 |  3.145s |     3.151s |
# | Initial point 2  |          258 |          0.52 |         9 |    0.95 |                4 |       0.8 |              0.3 |      0.01 |        0.1 |      0.7475 |           0.7558 |      0.4906 |           0.5082 |  2.799s |     6.019s |
# | Initial point 3  |          293 |          0.13 |         6 |     0.3 |                6 |       0.5 |              0.6 |         1 |          0 |      0.7522 |           0.7558 |       0.474 |           0.5082 |  3.325s |     9.413s |
# | Iteration 4      |          303 |          0.17 |         5 |    0.02 |               10 |       0.6 |              1.0 |       100 |          1 |         0.5 |           0.7558 |      0.0986 |           0.5082 |  1.862s |    11.529s |
# | Iteration 5      |          349 |          0.02 |         3 |    0.49 |               19 |       1.0 |              1.0 |       100 |          1 |         0.5 |           0.7558 |      0.0986 |           0.5082 |  1.796s |    13.580s |
# | Iteration 6      |           97 |          0.08 |         1 |    0.27 |                9 |       0.7 |              0.8 |         0 |         10 |      0.7442 |           0.7558 |      0.4684 |           0.5082 |  0.642s |    14.478s |
# | Iteration 7      |          190 |          0.01 |         6 |    0.91 |               13 |       0.6 |              0.8 |         0 |         10 |      0.7573 |           0.7573 |      0.4866 |           0.5082 |  2.346s |    17.081s |
#
# Results for XGBoost:
# Bayesian Optimization ---------------------------
# Best call --> Iteration 7
# Best parameters --> {'n_estimators': 190, 'learning_rate': 0.01, 'max_depth': 6, 'gamma': 0.91, 'min_child_weight': 13, 'subsample': 0.6, 'colsample_bytree': 0.8, 'reg_alpha': 0, 'reg_lambda': 10}
# Best evaluation --> roc_auc_ovr: 0.7573   f1_weighted: 0.4866
# Time elapsed: 17.341s
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.8183   f1_weighted: 0.5313
# Test evaluation --> roc_auc_ovr: 0.7765   f1_weighted: 0.5055
# Time elapsed: 0.630s
# Bootstrap ---------------------------------------
# Evaluation --> roc_auc_ovr: 0.7695 ± 0.0067   f1_weighted: 0.4511 ± 0.0305
# Time elapsed: 2.805s
# -------------------------------------------------
# Total time: 20.776s
#
#
# Running BO for CatBoost...
# | call             | n_estimators | learning_rate | max_depth | subsample | colsample_bylevel | reg_lambda | roc_auc_ovr | best_roc_auc_ovr | f1_weighted | best_f1_weighted |    time | total_time |
# | ---------------- | ------------ | ------------- | --------- | --------- | ----------------- | ---------- | ----------- | ---------------- | ----------- | ---------------- | ------- | ---------- |
# | Initial point 1  |          261 |          0.12 |         1 |       0.5 |               0.9 |          1 |      0.7571 |           0.7571 |      0.4779 |           0.4779 |  0.465s |     0.470s |
# | Initial point 2  |          488 |          0.03 |         6 |       1.0 |               0.3 |         10 |      0.7527 |           0.7571 |      0.4558 |           0.4779 |  6.071s |     6.610s |
# | Initial point 3  |          339 |          0.53 |         8 |       0.5 |               0.8 |          1 |      0.7283 |           0.7571 |       0.469 |           0.4779 | 16.439s |    23.118s |
# | Iteration 4      |          249 |          0.03 |         7 |       0.7 |               0.4 |        0.1 |      0.7509 |           0.7571 |      0.4869 |           0.4869 |  6.348s |    29.716s |
# | Iteration 5      |          170 |          0.22 |         6 |       0.6 |               0.6 |          0 |      0.7573 |           0.7573 |      0.4955 |           0.4955 |  2.414s |    32.383s |
# | Iteration 6      |          441 |          0.02 |         5 |       0.6 |               0.4 |          0 |      0.7518 |           0.7573 |      0.4882 |           0.4955 |  3.365s |    35.998s |
# | Iteration 7      |          423 |          0.05 |         2 |       0.5 |               0.3 |       0.01 |      0.7669 |           0.7669 |      0.4979 |           0.4979 |  0.794s |    37.044s |
#
# Results for CatBoost:
# Bayesian Optimization ---------------------------
# Best call --> Iteration 7
# Best parameters --> {'n_estimators': 423, 'learning_rate': 0.05, 'max_depth': 2, 'subsample': 0.5, 'colsample_bylevel': 0.3, 'reg_lambda': 0.01}
# Best evaluation --> roc_auc_ovr: 0.7669   f1_weighted: 0.4979
# Time elapsed: 37.302s
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.8785   f1_weighted: 0.6387
# Test evaluation --> roc_auc_ovr: 0.7983   f1_weighted: 0.5164
# Time elapsed: 0.203s
# Bootstrap ---------------------------------------
# Evaluation --> roc_auc_ovr: 0.772 ± 0.0107   f1_weighted: 0.4949 ± 0.0153
# Time elapsed: 0.852s
# -------------------------------------------------
# Total time: 38.358s
#
#
# Running BO for LightGBM...
# | call             | n_estimators | learning_rate | max_depth | num_leaves | min_child_weight | min_child_samples | subsample | colsample_bytree | reg_alpha | reg_lambda | roc_auc_ovr | best_roc_auc_ovr | f1_weighted | best_f1_weighted |    time | total_time |
# | ---------------- | ------------ | ------------- | --------- | ---------- | ---------------- | ----------------- | --------- | ---------------- | --------- | ---------- | ----------- | ---------------- | ----------- | ---------------- | ------- | ---------- |
# | Initial point 1  |          261 |          0.12 |         1 |         36 |               14 |                14 |       0.5 |              0.4 |         1 |        100 |      0.7424 |           0.7424 |      0.4753 |           0.4753 |  0.768s |     0.774s |
# | Initial point 2  |          204 |          0.78 |        -1 |         26 |                7 |                19 |       0.7 |              0.5 |         0 |       0.01 |      0.7289 |           0.7424 |      0.4827 |           0.4827 |  0.869s |     1.714s |
# | Initial point 3  |          337 |          0.04 |         2 |         32 |               14 |                20 |       0.7 |              0.5 |         1 |          1 |      0.7605 |           0.7605 |      0.5009 |           0.5009 |  1.132s |     2.916s |
# | Iteration 4      |          399 |          0.41 |         1 |         25 |               20 |                26 |       0.5 |              0.8 |       100 |       0.01 |         0.5 |           0.7605 |      0.1484 |           0.5009 |  0.503s |     3.705s |
# | Iteration 5      |          311 |          0.23 |         6 |         27 |                1 |                28 |       0.8 |              1.0 |         1 |       0.01 |      0.7535 |           0.7605 |      0.4984 |           0.5009 |  0.685s |     4.674s |
# | Iteration 6      |          191 |           0.1 |         1 |         30 |                6 |                15 |       1.0 |              0.3 |         1 |       0.01 |      0.7495 |           0.7605 |      0.4907 |           0.5009 |  0.564s |     5.523s |
# | Iteration 7      |           62 |          0.58 |         3 |         27 |               13 |                13 |       0.7 |              0.7 |        10 |         10 |       0.722 |           0.7605 |      0.4638 |           0.5009 |  0.204s |     6.012s |
#
# Results for LightGBM:
# Bayesian Optimization ---------------------------
# Best call --> Initial point 3
# Best parameters --> {'n_estimators': 337, 'learning_rate': 0.04, 'max_depth': 2, 'num_leaves': 32, 'min_child_weight': 14, 'min_child_samples': 20, 'subsample': 0.7, 'colsample_bytree': 0.5, 'reg_alpha': 1, 'reg_lambda': 1}
# Best evaluation --> roc_auc_ovr: 0.7605   f1_weighted: 0.5009
# Time elapsed: 6.300s
# Fit ---------------------------------------------
# Train evaluation --> roc_auc_ovr: 0.8566   f1_weighted: 0.6037
# Test evaluation --> roc_auc_ovr: 0.787   f1_weighted: 0.5096
# Time elapsed: 0.317s
# Bootstrap ---------------------------------------
# Evaluation --> roc_auc_ovr: 0.768 ± 0.011   f1_weighted: 0.478 ± 0.0116
# Time elapsed: 1.139s
# -------------------------------------------------
# Total time: 7.757s
#
#
# Final results ==================== >>
# Duration: 1m:40s
# -------------------------------------
# Gradient Boosting Machine --> roc_auc_ovr: 0.7566 ± 0.0061   f1_weighted: 0.4308 ± 0.0261
# XGBoost                   --> roc_auc_ovr: 0.7695 ± 0.0067   f1_weighted: 0.4511 ± 0.0305
# CatBoost                  --> roc_auc_ovr: 0.772 ± 0.0107   f1_weighted: 0.4949 ± 0.0153 !
# LightGBM                  --> roc_auc_ovr: 0.768 ± 0.011   f1_weighted: 0.478 ± 0.0116

# %% [markdown]
# #### Compare results - final table

# %%
atom.plot_results(figsize=(8,5))
# atom.plot_results("f1_weighted",figsize=(8,5)) <-- how to show F1_weighted?
atom.results
# Out:
#                                          metric_bo  time_bo  \
# Tree                                          None     None
# GBM       [0.7500830112452228, 0.4740967999809277]  22.827s
# XGB       [0.7645960282486175, 0.4746050621836613]  14.624s
# CatB      [0.7646548177994179, 0.4822783523002248]  28.829s
# LGB       [0.7757423097804267, 0.4986652515363528]   5.722s
# GBM_fe   [0.7570969600898563, 0.49625217615282863]  27.806s
# XGB_fe     [0.7572883220894612, 0.486580239568568]  17.341s
# CatB_fe  [0.7669249938146218, 0.49792487898960863]  37.302s
# LGB_fe     [0.760456496626395, 0.5009314028042954]   6.300s
#
#                                       metric_train  \
# Tree      [0.9964365661835731, 0.9337175449877864]
# GBM      [0.7867743232683171, 0.49490364106178053]
# XGB       [0.9111537643536732, 0.7148656560021315]
# CatB       [0.830234993291373, 0.5407768702011418]
# LGB       [0.8365003744966811, 0.5839456956321168]
# GBM_fe    [0.7882230602202076, 0.5009991146640244]
# XGB_fe    [0.8183326899171309, 0.5313371106922992]
# CatB_fe   [0.8785417918696707, 0.6387206093506455]
# LGB_fe    [0.8565964948040845, 0.6037163716126565]
#
#                                        metric_test time_fit  \
# Tree       [0.670755443407984, 0.4790655245479738]   0.015s
# GBM       [0.7846376370990996, 0.3982980155459547]   0.628s
# XGB      [0.7920752088893832, 0.49674088529510213]   0.699s
# CatB     [0.8011786786738857, 0.49602951959594815]   0.103s
# LGB       [0.8057490085982971, 0.5282436181499551]   0.163s
# GBM_fe    [0.755915811164019, 0.39994640370896223]   0.886s
# XGB_fe     [0.776455153060053, 0.5054793456453237]   0.630s
# CatB_fe   [0.7983350074350153, 0.5164254026408526]   0.203s
# LGB_fe    [0.7870365881233824, 0.5095622590613079]   0.317s
#
#                                     mean_bootstrap  \
# Tree                                          None
# GBM       [0.7658454527130338, 0.4387907269911895]
# XGB         [0.770019695583227, 0.489983679531316]
# CatB      [0.7795356796079618, 0.4802511990602999]
# LGB       [0.7797333643728892, 0.5000211478550401]
# GBM_fe   [0.7565898267606717, 0.43081945032793917]
# XGB_fe   [0.7694745591304144, 0.45114362937659597]
# CatB_fe  [0.7719650380042078, 0.49489339514553843]
# LGB_fe    [0.7679895355845958, 0.4780008414662973]
#
#                                          std_bootstrap time_bootstrap     time
# Tree                                              None           None   0.016s
# GBM       [0.008881012599669877, 0.017014323948331724]         3.060s  26.516s
# XGB       [0.009524106719565346, 0.028413501476214933]         2.978s  18.303s
# CatB      [0.007522025765807117, 0.026593523423678534]         0.395s  29.329s
# LGB        [0.010837657209438467, 0.02294852521002329]         0.488s   6.375s
# GBM_fe    [0.006107492686100371, 0.026129618173037328]         4.355s  33.047s
# XGB_fe   [0.0066850964321521515, 0.030469347317736345]         2.805s  20.776s
# CatB_fe    [0.01065516218462356, 0.015285471646278578]         0.852s  38.358s
# LGB_fe     [0.011016506216897173, 0.01164406222366525]         1.139s   7.757s

# %% [markdown]
# Observation:
# - And the winner is ...
# - ...on BO and FE

# %% [markdown]
# #### Learning curves

# %%
# atom.plot_learning_curve()
atom.plot_bo(figsize=(16,5))

# %%
with atom.canvas(2, 2, title="Models evaluation"):
    model_list = ["XGB","LGB"]# "CATB"]#, ]
    for m in model_list:
        atom.plot_evals(m, title=f"{m}", figsize=(8,5))

# %% [markdown]
# #### One model exploration - show-off

# %%
atom.plot_confusion_matrix("CATB",figsize=(8,5))

# %%
atom.plot_feature_importance("CATB", 12,figsize=(8,5))
# atom.feature_importance

# %%
# atom.bar_plot('CATB', show=10,figsize=(8,5))  # <--don't try on CATB, kernel dies

# %%
atom.plot_probabilities('CATB',figsize=(8,5))

# %% [markdown]
# ### Final thoughts

# %% [markdown]
# Despite apparent failures of hyperparameters' optimization and feature engineering on a
# particular dataset, all gradient boosted models in question showed robust performance.
#
# Future steps:
# - reduce the number of hyperparameters being tuned (impossible now for technical reasons)
# - drastically increase the number of calls for BO
# - give the models a try on a different dataset
# - implement similar pipeline logic in sklearn (maybe)
# - CatBoost crashes ATOM in many function calls, could not explore all useful features of the
#     library, will try to run in a different environment (conda may be a culprit)
